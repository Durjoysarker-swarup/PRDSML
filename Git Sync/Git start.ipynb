# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/NBICT LAB PRDSML-B-7"
# !git config --global user.email "durjoysarker78@gmail.com"
# !git config --global user.name "Durjoysarker-swarup"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/NBICT LAB PRDSML-B-7

# %%
# !git add .
# !git commit -m "Completed data preprocessing"
# Out:
# [main cf3d700] Completed data preprocessing
#  3 files changed, 186 insertions(+), 2 deletions(-)
#  rewrite 2. Data Prepossessing/ Data Preprocessing in Python.ipynb (95%)
#  create mode 100644 2. Data Prepossessing/titanic.csv
#  rewrite Git Sync/Git start.ipynb (80%)

# %%
# !git push  https://Durjoysarker-swarup:@github.com/Durjoysarker-swarup/PRDSML.git main
# Out:
# Enumerating objects: 12, done.
# Counting objects: 100% (12/12), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (7/7), 3.73 KiB | 62.00 KiB/s, done.
# Total 7 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/Durjoysarker-swarup/PRDSML.git
#    b385b53..cf3d700  main -> main

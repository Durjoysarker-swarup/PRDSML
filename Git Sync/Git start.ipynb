# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/NBICT LAB PRDSML-B-7"
# !git config --global user.email "durjoysarker78@gmail.com"
# !git config --global user.name "Durjoysarker-swarup"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/NBICT LAB PRDSML-B-7

# %%
# !git add .
# !git commit -m "flow control in python"
# Out:
# [main 8c8e262] flow control in python
#  4 files changed, 2 insertions(+), 1 deletion(-)
#  rename "Day-2+3 \360\237\221\211 Lists in Python/Day-2+3 \360\237\221\211 Lists in Python (Part-1).ipynb" => "1. Lists in Python (Day-2+3)/Day-2+3 \360\237\221\211 Lists in Python (Part-1).ipynb" (100%)
#  create mode 100644 2. Flow Control in Python (Day-4+5+6 )/Flow Control in Python .ipynb
#  rewrite Git Sync/Git start.ipynb (79%)
#  rename "Day-1 \360\237\221\211 Environment Setup/FirstFile.ipynb" => "\360\237\221\211 Environment Setup (Day-1)/FirstFile.ipynb" (100%)

# %%
# !git push  https://Durjoysarker-swarup:@github.com/Durjoysarker-swarup/PRDSML.git main
# Out:
# Enumerating objects: 9, done.
# Counting objects: 100% (9/9), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (6/6), 2.88 KiB | 147.00 KiB/s, done.
# Total 6 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/Durjoysarker-swarup/PRDSML.git
#    eab590f..8c8e262  main -> main

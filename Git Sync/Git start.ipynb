# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/NBICT LAB PRDSML-B-7"
# !git config --global user.email "durjoysarker78@gmail.com"
# !git config --global user.name "Durjoysarker-swarup"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/NBICT LAB PRDSML-B-7

# %%
# !git add .
# !git commit -m "Started data preprocessing"
# Out:
# [main b385b53] Started data preprocessing
#  3 files changed, 13 insertions(+), 1 deletion(-)
#  create mode 100644 2. Data Prepossessing/ Data Preprocessing in Python.ipynb
#  create mode 100644 2. Data Prepossessing/Data.csv
#  rewrite Git Sync/Git start.ipynb (78%)

# %%
# !git push  https://Durjoysarker-swarup:@github.com/Durjoysarker-swarup/PRDSML.git main
# Out:
# Enumerating objects: 10, done.
# Counting objects: 100% (10/10), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (7/7), 3.45 KiB | 176.00 KiB/s, done.
# Total 7 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/Durjoysarker-swarup/PRDSML.git
#    74911b7..b385b53  main -> main

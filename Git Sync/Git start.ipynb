# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/NBICT LAB PRDSML-B-7"
# !git config --global user.email "durjoysarker78@gmail.com"
# !git config --global user.name "Durjoysarker-swarup"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/NBICT LAB PRDSML-B-7

# %%
# !git add .
# !git commit -m "Histogram and Barplot"
# Out:
# [main f22aee7] Histogram and Barplot
#  6 files changed, 86 insertions(+), 2 deletions(-)
#  create mode 100644 8. Data Visualization/50_Startups.csv
#  create mode 100644 8. Data Visualization/Boxplot Using Matplotlib.ipynb
#  create mode 100644 8. Data Visualization/Histogram and Barplot Using Matplotlib.ipynb
#  create mode 100644 8. Data Visualization/Salary_Data.csv
#  rewrite Git Sync/Git start.ipynb (100%)

# %%
# !git push  https://Durjoysarker-swarup:@github.com/Durjoysarker-swarup/PRDSML.git main
# Out:
# Enumerating objects: 16, done.
# Counting objects: 100% (16/16), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (10/10), done.
# Writing objects: 100% (11/11), 240.17 KiB | 4.29 MiB/s, done.
# Total 11 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 3 local objects.
# To https://github.com/Durjoysarker-swarup/PRDSML.git
#    a394452..f22aee7  main -> main

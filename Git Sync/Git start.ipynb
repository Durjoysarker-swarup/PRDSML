# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/NBICT LAB PRDSML-B-7"
# !git config --global user.email "durjoysarker78@gmail.com"
# !git config --global user.name "Durjoysarker-swarup"
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/NBICT LAB PRDSML-B-7

# %%
# !git add .
# !git commit -m "Python basics completed"
# Out:
# [main 74911b7] Python basics completed
#  4 files changed, 2 insertions(+), 1 deletion(-)
#  rename "1. Lists in Python (Day-2+3)/Day-2+3 \360\237\221\211 Lists in Python (Part-1).ipynb" => "1. Python Basic/1. Lists in Python (Day-2+3)/Day-2+3 \360\237\221\211 Lists in Python (Part-1).ipynb" (100%)
#  rename {2. Flow Control in Python (Day-4+5+6 ) => 1. Python Basic/2. Flow Control in Python (Day-4+5+6 )}/Flow Control in Python .ipynb (100%)
#  create mode 100644 "1. Python Basic/3. Function in Python/Day-8 \360\237\221\211 Functions in Python.ipynb"
#  rewrite Git Sync/Git start.ipynb (75%)

# %%
# !git push  https://Durjoysarker-swarup:@github.com/Durjoysarker-swarup/PRDSML.git main
# Out:
# Enumerating objects: 10, done.
# Counting objects: 100% (10/10), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (6/6), done.
# Writing objects: 100% (7/7), 3.11 KiB | 227.00 KiB/s, done.
# Total 7 (delta 1), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (1/1), completed with 1 local object.
# To https://github.com/Durjoysarker-swarup/PRDSML.git
#    7593af0..74911b7  main -> main

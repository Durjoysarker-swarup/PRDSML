# %%
from google.colab import drive
drive.mount('/content/drive')
# %cd "/content/drive/MyDrive/NBICT LAB PRDSML-B-7"
# !git config --global user.email "durjoysarker78@gmail.com"
# !git config --global user.name "Durjoysarker-swarup"

# %%
# !git add .
# !git commit -m "Started the PCA"
# Out:
# [main a360934] Started the PCA
#  5 files changed, 361 insertions(+), 2 deletions(-)
#  rewrite 6.  K-Means Clustering/K-Means Clustering.ipynb (96%)
#  create mode 100644 7. Principal Component Analysis/ Principal Component Analysis.ipynb
#  create mode 100644 7. Principal Component Analysis/Wine.csv
#  create mode 100644 7. Principal Component Analysis/Wine_3_Clusters.csv
#  rewrite Git Sync/Git start.ipynb (77%)

# %%
# !git push  https://Durjoysarker-swarup:@github.com/Durjoysarker-swarup/PRDSML.git main
# Out:
# Enumerating objects: 15, done.
# Counting objects: 100% (15/15), done.
# Delta compression using up to 2 threads
# Compressing objects: 100% (9/9), done.
# Writing objects: 100% (10/10), 112.06 KiB | 1.84 MiB/s, done.
# Total 10 (delta 3), reused 0 (delta 0), pack-reused 0
# remote: Resolving deltas: 100% (3/3), completed with 2 local objects.
# To https://github.com/Durjoysarker-swarup/PRDSML.git
#    de0934b..a360934  main -> main

# %% [markdown]
# # Day-4+5+6+7 👉 Flow Control in Python

# %% [markdown]
# ## if…else… Statements

# %%
name = input("What is your name? ")
passward = "swardfish"
if name == "Mary":
    print("Hello, Mary")
    if passward == "swordfish":
        print("Access granted.")
    else:
        print("Wrong passward.")
else:
    print("Hello, stranger.")
# Out:
# What is your name? Mary
# Hello, Mary
# Wrong passward.

# %% [markdown]
# ## elif Statements

# %%
name = 'Carol'
age = 3000
if name == 'Alice':
    print('Hi, Alice.')
elif age < 12:
    print('You are not Alice, kiddo.')
elif age > 2000:
    print('Unlike you, Alice is not an undead, immortal vampire.')
elif age > 100:
    print('You are not Alice, grannie.')
# Out:
# Unlike you, Alice is not an undead, immortal vampire.

# %%
name = 'Carol'
age = 30
if name == 'Alice':
    print('Hi, Alice.')
elif age < 12:
    print('You are not Alice, kiddo.')
else:
    print('You are neither Alice nor a little kid.')
# Out:
# You are neither Alice nor a little kid.

# %% [markdown]
# ## While loop statement

# %%
spam = 0
if spam < 5:
    print('Hello, world.')
    spam = spam + 1
    print(spam)
# Out:
# Hello, world.
# 1

# %% [markdown]
# - while ->Run the until the case is false.

# %%
spam = 0
while spam < 5:
    print('Hello, world.')
    spam = spam + 1
    print(spam)
# Out:
# Hello, world.
# 1
# Hello, world.
# 2
# Hello, world.
# 3
# Hello, world.
# 4
# Hello, world.
# 5

# %% [markdown]
# ## break statement

# %% [markdown]
# != -> not equal to

# %%
name = ""
while name != "your name":
    print("Please type your name.")
    name = input()
print("Thank you!")
# Out:
# Please type your name.
# swarup
# Please type your name.
# durjoy
# Please type your name.
# your name
# Thank you!

# %%
while True:
    name = input("who are you? ")
    if name == "your name":
      break
print("Thank you!")
# Out:
# who are you? swarup
# who are you? durjoy
# who are you? your name
# Thank you!

# %% [markdown]
# ## continue Statement

# %%
while True:
  name = input("Who are you? ")
  if name != "Joe":
    continue
  password = input("Hello, Joe. What is the password? (It is a fish.) ")
  if password == "swordfish":
    break
print("Access granted.")
# Out:
# Who are you? swarup
# Who are you? Joe
# Hello, Joe. What is the password? (It is a fish.) shark
# Who are you? Joe
# Hello, Joe. What is the password? (It is a fish.) swordfish
# Access granted.

# %% [markdown]
# ## for Loop and the range() function

# %%
print("My name is")
for i in range(5):
  print("swarup five times. ",i)
# Out:
# My name is
# swarup five times.  0
# swarup five times.  1
# swarup five times.  2
# swarup five times.  3
# swarup five times.  4

# %%
#adding 1 to 100
total = 0
for num in range(101):
  total = total + num
print(total)
# Out:
# 5050

# %%
i = 0
for i in range(10):
  i = i + i
print(i)
# Out:
# 18

# %% [markdown]
# ## The starting, stoping, and steping arugument to range()

# %%
for i in range(0,10,2):
  print(i)
# Out:
# 0
# 2
# 4
# 6
# 8

# %%
for i in range(50,0,-5):
  print(i)
# Out:
# 50
# 45
# 40
# 35
# 30
# 25
# 20
# 15
# 10
# 5

# %% [markdown]
# ## Importing Modules

# %%
import random
for i in range(5):
  print(random.randint(1,10))
# Out:
# 4
# 1
# 6
# 5
# 5

# %%
from random import randint
for i in range(5):
  print(randint(1,10))

# %% [markdown]
# ## A short program: Guess the Number

# %%
import random
secretNumber = random.randint(1, 20)
print('I am thinking of a number between 1 and 20.')

# Ask the player to guess 6 times.
for guessesTaken in range(1, 7):
    print('Take a guess.')
    guess = int(input())

    if guess < secretNumber:
        print('Your guess is too low.')
    elif guess > secretNumber:
        print('Your guess is too high.')
    else:
        break    # This condition is the correct guess!

if guess == secretNumber:
    print('Good job! You guessed my number in ' , guessesTaken , 'guesses')
else:
    print('Nope. The number I was thinking of was ' , secretNumber, ".")
# Out:
# I am thinking of a number between 1 and 20.
# Take a guess.
# 5
# Your guess is too high.
# Take a guess.
# 3
# Your guess is too high.
# Take a guess.
# 2
# Good job! You guessed my number in  3 guesses

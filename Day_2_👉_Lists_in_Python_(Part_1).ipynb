# %% [markdown]
# <a href="https://colab.research.google.com/github/Durjoysarker-swarup/PRDSML/blob/main/Day_2_%F0%9F%91%89_Lists_in_Python_(Part_1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Day-2 👉 Lists in Python (Part-1)

# %% [markdown]
# ### The List Data Type

# %%
[1, 2, 3]
# Out:
# [1, 2, 3]

# %%
['cat', 'bat', 'rat', 'elephant']
# Out:
# ['cat', 'bat', 'rat', 'elephant']

# %%
# True -> boolean data type
# None -> Reversed keyword
# 12 -> integer
# 3.1416 -> float
["hello", True, 12, 3.1416, None]
# Out:
# ['hello', True, 12, 3.1416, None]

# %% [markdown]
# ### Assignment operator

# %%
spam = ['cat', 'bat', 'rat', 'elephant']

# %%
spam
# Out:
# ['cat', 'bat', 'rat', 'elephant']

# %% [markdown]
# ### Getting individual value in a list with indexes

# %%
spam = ['cat', 'bat', 'rat', 'elephant']

# %%
['cat', 'bat', 'rat', 'elephant'][2]
# Out:
# 'rat'

# %%
spam[0]
# Out:
# 'cat'

# %%
spam[1]
# Out:
# 'bat'

# %% [markdown]
# #### Concatination operator

# %% [markdown]
# When there is a string value in any or both side of the +, then it is called concatination operator.
#
# ---
#
#
# of both side have the string or float then it is called addition operator.

# %%
"hello, " + spam[2]
# Out:
# 'hello, rat'

# %%
spam[int(1.0)]
# Out:
# 'bat'

# %%
spam1 = [["cat", "bat", "rat"], [20, 30, 40, 50], ["a", "b"]]

# %%
spam[1][2]
# Out:
# 40

# %% [markdown]
# ### Negative Indexes

# %%
spam = ['cat', 'bat', 'rat', 'elephant']

# %%
spam[-2]
# Out:
# 'rat'

# %% [markdown]
# The elephant is afraid of the bat

# %%
sentance = "the " + spam[-1] + " afraid of the " + spam[-3]
sentance
# Out:
# 'the elephant afraid of the bat'

# %% [markdown]
# ### Getting a list from another list with Slices

# %%
spam = ['cat', 'bat', 'rat', 'elephant']

# %%
# [starting index: ending index+1]
spam[1:3]
# Out:
# ['bat', 'rat']

# %%
spam[1:-1]
# Out:
# ['bat', 'rat']

# %%
spam[1:]
# Out:
# ['bat', 'rat', 'elephant']

# %%
spam[:3]
# Out:
# ['cat', 'bat', 'rat']

# %% [markdown]
# ### Getting a list's length

# %%
len(spam)
# Out:
# 4
